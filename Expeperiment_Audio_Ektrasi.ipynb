# %% [markdown]
# # Import Libraries

# %%
# !pip install openai-whisper torch torchaudio librosa soundfile numpy ipywidgets
# Out:
# Collecting openai-whisper
#   Downloading openai_whisper-20250625.tar.gz (803 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 3.3 MB/s  0:00:00.4 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch in /home/kisara/miniconda3/lib/python3.13/site-packages (2.12.0)
# Collecting torchaudio
#   Downloading torchaudio-2.11.0-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (6.9 kB)
# Collecting librosa
#   Downloading librosa-0.11.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting soundfile
#   Downloading soundfile-0.14.0-py2.py3-none-manylinux_2_28_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: numpy in /home/kisara/miniconda3/lib/python3.13/site-packages (2.5.0)
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: more-itertools in /home/kisara/miniconda3/lib/python3.13/site-packages (from openai-whisper) (11.0.2)
# Collecting numba (from openai-whisper)
#   Downloading numba-0.66.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.7 kB)
# Collecting tiktoken (from openai-whisper)
#   Downloading tiktoken-0.13.0-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tqdm in /home/kisara/miniconda3/lib/python3.13/site-packages (from openai-whisper) (4.68.2)
# Requirement already satisfied: triton>=2 in /home/kisara/miniconda3/lib/python3.13/site-packages (from openai-whisper) (3.7.0)
# Requirement already satisfied: filelock in /home/kisara/miniconda3/lib/python3.13/site-packages (from torch) (3.29.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/kisara/miniconda3/lib/python3.13/site-packages (from torch) (4.15.0)
# Collecting setuptools<82 (from torch)
#   Downloading setuptools-81.0.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: sympy>=1.13.3 in /home/kisara/miniconda3/lib/python3.13/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/kisara/miniconda3/lib/python3.13/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /home/kisara/miniconda3/lib/python3.13/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/kisara/miniconda3/lib/python3.13/site-packages (from torch) (2026.4.0)
# Requirement already satisfied: cuda-toolkit==13.0.2 in /home/kisara/miniconda3/lib/python3.13/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.2)
# Requirement already satisfied: nvidia-cublas<=13.1.1.3,>=13.1.0.3 in /home/kisara/miniconda3/lib/python3.13/site-packages (from torch) (13.1.1.3)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /home/kisara/miniconda3/lib/python3.13/site-packages (from torch) (13.3.1)
# Requirement already satisfied: nvidia-cudnn-cu13==9.20.0.48 in /home/kisara/miniconda3/lib/python3.13/site-packages (from torch) (9.20.0.48)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.1 in /home/kisara/miniconda3/lib/python3.13/site-packages (from torch) (0.8.1)
# Requirement already satisfied: nvidia-nccl-cu13==2.29.7 in /home/kisara/miniconda3/lib/python3.13/site-packages (from torch) (2.29.7)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /home/kisara/miniconda3/lib/python3.13/site-packages (from torch) (3.4.5)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /home/kisara/miniconda3/lib/python3.13/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /home/kisara/miniconda3/lib/python3.13/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (12.0.0.61)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /home/kisara/miniconda3/lib/python3.13/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /home/kisara/miniconda3/lib/python3.13/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /home/kisara/miniconda3/lib/python3.13/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /home/kisara/miniconda3/lib/python3.13/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /home/kisara/miniconda3/lib/python3.13/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (12.6.3.3)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /home/kisara/miniconda3/lib/python3.13/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.88)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /home/kisara/miniconda3/lib/python3.13/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.88)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /home/kisara/miniconda3/lib/python3.13/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.85)
# Requirement already satisfied: cuda-pathfinder>=1.4.2 in /home/kisara/miniconda3/lib/python3.13/site-packages (from cuda-bindings<14,>=13.0.3->torch) (1.5.5)
# Collecting audioread>=2.1.9 (from librosa)
#   Downloading audioread-3.1.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: scipy>=1.6.0 in /home/kisara/miniconda3/lib/python3.13/site-packages (from librosa) (1.18.0)
# Requirement already satisfied: scikit-learn>=1.1.0 in /home/kisara/miniconda3/lib/python3.13/site-packages (from librosa) (1.9.0)
# Requirement already satisfied: joblib>=1.0 in /home/kisara/miniconda3/lib/python3.13/site-packages (from librosa) (1.5.3)
# Requirement already satisfied: decorator>=4.3.0 in /home/kisara/miniconda3/lib/python3.13/site-packages (from librosa) (5.3.1)
# Collecting pooch>=1.1 (from librosa)
#   Downloading pooch-1.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting soxr>=0.3.2 (from librosa)
#   Downloading soxr-1.1.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.8 kB)
# Collecting lazy_loader>=0.1 (from librosa)
#   Downloading lazy_loader-0.5-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: msgpack>=1.0 in /home/kisara/miniconda3/lib/python3.13/site-packages (from librosa) (1.2.0)
# Collecting standard-aifc (from librosa)
#   Downloading standard_aifc-3.13.0-py3-none-any.whl.metadata (969 bytes)
# Collecting standard-sunau (from librosa)
#   Downloading standard_sunau-3.13.0-py3-none-any.whl.metadata (914 bytes)
# Requirement already satisfied: cffi>=1.0 in /home/kisara/miniconda3/lib/python3.13/site-packages (from soundfile) (2.0.0)
# Requirement already satisfied: comm>=0.1.3 in /home/kisara/miniconda3/lib/python3.13/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /home/kisara/miniconda3/lib/python3.13/site-packages (from ipywidgets) (9.14.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/kisara/miniconda3/lib/python3.13/site-packages (from ipywidgets) (5.15.0)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets)
#   Downloading widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets)
#   Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: pycparser in /home/kisara/miniconda3/lib/python3.13/site-packages (from cffi>=1.0->soundfile) (3.0)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/kisara/miniconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in /home/kisara/miniconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in /home/kisara/miniconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: pexpect>4.6 in /home/kisara/miniconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/kisara/miniconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: psutil>=7 in /home/kisara/miniconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (7.0.0)
# Requirement already satisfied: pygments>=2.14.0 in /home/kisara/miniconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in /home/kisara/miniconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in /home/kisara/miniconda3/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /home/kisara/miniconda3/lib/python3.13/site-packages (from jedi>=0.18.2->ipython>=6.1.0->ipywidgets) (0.8.7)
# Requirement already satisfied: packaging in /home/kisara/miniconda3/lib/python3.13/site-packages (from lazy_loader>=0.1->librosa) (26.0)
# Collecting llvmlite<0.49,>=0.48.0dev0 (from numba->openai-whisper)
#   Downloading llvmlite-0.48.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.0 kB)
# Collecting numpy
#   Downloading numpy-2.4.6-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /home/kisara/miniconda3/lib/python3.13/site-packages (from pexpect>4.6->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/kisara/miniconda3/lib/python3.13/site-packages (from pooch>=1.1->librosa) (4.9.4)
# Requirement already satisfied: requests>=2.19.0 in /home/kisara/miniconda3/lib/python3.13/site-packages (from pooch>=1.1->librosa) (2.34.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/kisara/miniconda3/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/kisara/miniconda3/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/kisara/miniconda3/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /home/kisara/miniconda3/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2026.6.17)
# Requirement already satisfied: narwhals>=2.0.1 in /home/kisara/miniconda3/lib/python3.13/site-packages (from scikit-learn>=1.1.0->librosa) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /home/kisara/miniconda3/lib/python3.13/site-packages (from scikit-learn>=1.1.0->librosa) (3.6.0)
# Requirement already satisfied: executing>=1.2.0 in /home/kisara/miniconda3/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/kisara/miniconda3/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure_eval in /home/kisara/miniconda3/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/kisara/miniconda3/lib/python3.13/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/kisara/miniconda3/lib/python3.13/site-packages (from jinja2->torch) (3.0.2)
# Collecting standard-chunk (from standard-aifc->librosa)
#   Downloading standard_chunk-3.13.0-py3-none-any.whl.metadata (860 bytes)
# Collecting audioop-lts (from standard-aifc->librosa)
#   Downloading audioop_lts-0.2.2-cp313-abi3-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: regex in /home/kisara/miniconda3/lib/python3.13/site-packages (from tiktoken->openai-whisper) (2026.5.9)
# Downloading setuptools-81.0.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 3.2 MB/s  0:00:00m 3.3 MB/s eta 0:00:01
# Downloading torchaudio-2.11.0-cp313-cp313-manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 3.3 MB/s  0:00:00m 3.3 MB/s eta 0:00:01
# Downloading librosa-0.11.0-py3-none-any.whl (260 kB)
# Downloading soundfile-0.14.0-py2.py3-none-manylinux_2_28_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 3.3 MB/s  0:00:00 eta 0:00:010:00:01
# Downloading ipywidgets-8.1.8-py3-none-any.whl (139 kB)
# Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 3.0 MB/s  0:00:00m 3.3 MB/s eta 0:00:01
# Downloading widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 3.8 MB/s  0:00:004.0 MB/s eta 0:00:01
# Downloading audioread-3.1.0-py3-none-any.whl (23 kB)
# Downloading lazy_loader-0.5-py3-none-any.whl (8.0 kB)
# Downloading numba-0.66.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 3.1 MB/s  0:00:01m 3.1 MB/s eta 0:00:01
# Downloading numpy-2.4.6-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 4.8 MB/s  0:00:03a 0:00:01m eta 0:00:01
# Downloading llvmlite-0.48.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (59.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 MB 5.8 MB/s  0:00:10 eta 0:00:010:01:01
# Downloading pooch-1.9.0-py3-none-any.whl (67 kB)
# Downloading soxr-1.1.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (240 kB)
# Downloading standard_aifc-3.13.0-py3-none-any.whl (10 kB)
# Downloading audioop_lts-0.2.2-cp313-abi3-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (85 kB)
# Downloading standard_chunk-3.13.0-py3-none-any.whl (4.9 kB)
# Downloading standard_sunau-3.13.0-py3-none-any.whl (7.4 kB)
# Downloading tiktoken-0.13.0-cp313-cp313-manylinux_2_28_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 6.1 MB/s  0:00:00
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20250625-py3-none-any.whl size=803979 sha256=0bd0e00419f8b77d82c30b144de6dfb6c6bb0800c5cf9cdef9e309c0892d1844
#   Stored in directory: /home/kisara/.cache/pip/wheels/ca/58/d5/fb4539ad74c3ca81eb40f7eda020ac77d080b33ad57449d485
# Successfully built openai-whisper
# Installing collected packages: torchaudio, standard-chunk, widgetsnbextension, setuptools, numpy, llvmlite, lazy_loader, jupyterlab_widgets, audioop-lts, tiktoken, standard-sunau, standard-aifc, soxr, soundfile, pooch, numba, ipywidgets, audioread, librosa, openai-whisper
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 82.0.1
#     Uninstalling setuptools-82.0.1:;5;237m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/20 [setuptools]
#       Successfully uninstalled setuptools-82.0.1━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/20 [setuptools]
#   Attempting uninstall: numpy0m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/20 [setuptools]
#     Found existing installation: numpy 2.5.0━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/20 [setuptools]
#     Uninstalling numpy-2.5.0:╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/20 [numpy]]
#       Successfully uninstalled numpy-2.5.0━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/20 [numpy]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20/20 [openai-whisper]18/20 [librosa]e]
# Successfully installed audioop-lts-0.2.2 audioread-3.1.0 ipywidgets-8.1.8 jupyterlab_widgets-3.0.16 lazy_loader-0.5 librosa-0.11.0 llvmlite-0.48.0 numba-0.66.0 numpy-2.4.6 openai-whisper-20250625 pooch-1.9.0 setuptools-81.0.0 soundfile-0.14.0 soxr-1.1.0 standard-aifc-3.13.0 standard-chunk-3.13.0 standard-sunau-3.13.0 tiktoken-0.13.0 torchaudio-2.11.0 widgetsnbextension-4.0.15

# %%
# !pip install sounddevice
# Out:
# Collecting sounddevice
#   Downloading sounddevice-0.5.5-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: cffi in /home/kisara/miniconda3/lib/python3.13/site-packages (from sounddevice) (2.0.0)
# Requirement already satisfied: pycparser in /home/kisara/miniconda3/lib/python3.13/site-packages (from cffi->sounddevice) (3.0)
# Downloading sounddevice-0.5.5-py3-none-any.whl (32 kB)
# Installing collected packages: sounddevice
# Successfully installed sounddevice-0.5.5

# %%
import whisper
import torch
import torchaudio
import torchaudio.transforms as T
import librosa
import librosa.display
import soundfile as sf
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Input Audio

# %%
audio_file = "audio/r1.mp3"

audio_raw, sample_rate = librosa.load(audio_file, sr=None, mono=False)

# %%
print(f"Audio file: {audio_file}")
print(f"Sample rate: {sample_rate}")
print(f"Audio shape: {audio_raw.shape}")
print(f"Audio duration: {librosa.get_duration(y=audio_raw, sr=sample_rate)} seconds")
# Out:
# Audio file: audio/r1.mp3
# Sample rate: 44100
# Audio shape: (2, 423936)
# Audio duration: 9.613061224489796 seconds

# %% [markdown]
# # Preprocessing (Esktras Audio)

# %%
TARGET_SR = 16000

# Stereo → Mono
if audio_raw.ndim > 1:
    audio_mono = audio_raw.mean(axis=0)
    print(f"[PRE-1] Stereo → Mono: {audio_raw.shape} → {audio_mono.shape}")
else:
    audio_mono = audio_raw
    print(f"[PRE-1] Sudah Mono   : {audio_mono.shape}")

# Resample ke 16kHz
if sample_rate != TARGET_SR:
    audio_resampled = librosa.resample(
        audio_mono, orig_sr=sample_rate, target_sr=TARGET_SR
    )
    print(f"[PRE-2] Resample: {sample_rate} Hz → {TARGET_SR} Hz")
else:
    audio_resampled = audio_mono
    print(f"[PRE-2] Sample rate sudah {TARGET_SR} Hz, skip resample")

# Normalize amplitude [-1, 1]
max_val = np.max(np.abs(audio_resampled))
if max_val > 0:
    audio_normalized = audio_resampled / max_val
else:
    audio_normalized = audio_resampled
print(f"[PRE-3] Normalized  | min={audio_normalized.min():.3f}, max={audio_normalized.max():.3f}")

# Pad / Trim ke 30 detik
audio_padded = whisper.pad_or_trim(audio_normalized.astype(np.float32))
print(f"[PRE-4] Pad/Trim    | Shape: {audio_padded.shape} ({len(audio_padded)/TARGET_SR:.1f} detik)")

# Log-Mel Spectrogram
mel_tensor = whisper.log_mel_spectrogram(audio_padded)
print(f"[PRE-5] Log-Mel     | Shape: {mel_tensor.shape}  (80 bands × 3000 frames)")
# Out:
# [PRE-1] Stereo → Mono: (2, 423936) → (423936,)
# [PRE-2] Resample: 44100 Hz → 16000 Hz
# [PRE-3] Normalized  | min=-1.000, max=0.960
# [PRE-4] Pad/Trim    | Shape: (480000,) (30.0 detik)
# [PRE-5] Log-Mel     | Shape: torch.Size([80, 3000])  (80 bands × 3000 frames)

# %%
fig, axes = plt.subplots(2, 1, figsize=(14, 6))

# Waveform
axes[0].plot(np.linspace(0, len(audio_padded)/TARGET_SR, len(audio_padded)),
             audio_padded, linewidth=0.5, color='steelblue')
axes[0].set_title("Waveform setelah preprocessing", fontsize=12)
axes[0].set_xlabel("Waktu (detik)")
axes[0].set_ylabel("Amplitude")
axes[0].set_xlim([0, 30])
axes[0].axhline(0, color='gray', linewidth=0.5, linestyle='--')

# Log-Mel Spectrogram
mel_np = mel_tensor.numpy()
img = axes[1].imshow(mel_np, aspect='auto', origin='lower',
                     extent=[0, 30, 0, 80], cmap='magma')
axes[1].set_title("Log-Mel Spectrogram (80 bands × 3000 frames)", fontsize=12)
axes[1].set_xlabel("Waktu (detik)")
axes[1].set_ylabel("Mel Bands")
plt.colorbar(img, ax=axes[1], label="Log Energy")

plt.tight_layout()
plt.savefig("savefig/preprocessing_output.png", dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Encoder/Decoder (Whisper)

# %%
MODEL_SIZE = "small"
LANGUAGE   = "id"
device = "cuda" if torch.cuda.is_available() else "cpu"
model  = whisper.load_model(MODEL_SIZE, device=device)
# Out:
# 100%|███████████████████████████████████████| 461M/461M [01:17<00:00, 6.21MiB/s]

# %%
print(f"model size: {MODEL_SIZE}, language: {LANGUAGE}, device: {device}")
# Out:
# model size: small, language: id, device: cuda

# %%
mel_input = mel_tensor.unsqueeze(0).to(device)   

with torch.no_grad():
    audio_features = model.encoder(mel_input)    

print(f"Input shape : {mel_input.shape}")
print(f"Audio features shape : {audio_features.shape}")
# Out:
# Input shape : torch.Size([1, 80, 3000])
# Audio features shape : torch.Size([1, 1500, 768])

# %%
options = whisper.DecodingOptions(
    language           = LANGUAGE,
    without_timestamps = False, 
    beam_size          = 5,          
    temperature        = 0.0,
    fp16               = True if device == "cuda" else False
)
with torch.no_grad():
    decode_result = whisper.decode(model, mel_tensor.to(device), options)

# Raw token IDs sebelum dikonversi ke teks
raw_tokens = decode_result.tokens
print(f"Jumlah token    : {len(raw_tokens)}")
print(f"Token IDs (raw) : {raw_tokens[:20]} ...")
print(f"Log probability : {decode_result.avg_logprob:.4f}")
print(f"No speech prob  : {decode_result.no_speech_prob:.4f}")
# Out:
# Jumlah token    : 21
# Token IDs (raw) : [50364, 591, 292, 1063, 5948, 9994, 502, 21112, 3282, 9162, 84, 11, 15284, 374, 502, 21112, 2443, 9162, 84, 2478] ...
# Log probability : -0.8288
# No speech prob  : 0.1504

# %%
# tokenizer Whisper
tokenizer = whisper.tokenizer.get_tokenizer(
    multilingual = True,
    language     = LANGUAGE,
    task         = "transcribe"
)

# special tokens (timestamp, SOT, EOT)
SPECIAL_TOKEN_IDS = set(tokenizer.sot_sequence) | {
    tokenizer.eot,
    tokenizer.no_speech,
    tokenizer.translate,
    tokenizer.transcribe,
}

# timestamp token range: 50364 – 51865
filtered_tokens = [
    t for t in raw_tokens
    if t not in SPECIAL_TOKEN_IDS and not (50264 <= t <= 51865)
]

# Decode token-by-token
token_to_str_map = {}
for i, token_id in enumerate(filtered_tokens[:15]):
    substr = tokenizer.decode([token_id])
    token_to_str_map[token_id] = substr
    print(f"  Token[{i:02d}] ID={token_id:6d} → '{substr}'")

# Decode semua token
full_text = tokenizer.decode(filtered_tokens)
print(f"\n Full string ({len(full_text)} karakter):")
print("-" * 60)
print(full_text)
print("-" * 60)
# Out:
#   Token[00] ID=   591 → ' K'
#   Token[01] ID=   292 → 'ed'
#   Token[02] ID=  1063 → 'ung'
#   Token[03] ID=  5948 → ' ber'
#   Token[04] ID=  9994 → 'asa'
#   Token[05] ID=   502 → ' 1'
#   Token[06] ID= 21112 → ' kilo'
#   Token[07] ID=  3282 → ' 17'
#   Token[08] ID=  9162 → ' rib'
#   Token[09] ID=    84 → 'u'
#   Token[10] ID=    11 → ','
#   Token[11] ID= 15284 → ' tel'
#   Token[12] ID=   374 → 'ur'
#   Token[13] ID=   502 → ' 1'
#   Token[14] ID= 21112 → ' kilo'
#
#  Full string (54 karakter):
# ------------------------------------------------------------
#  Kedung berasa 1 kilo 17 ribu, telur 1 kilo 18 ribu ya
# ------------------------------------------------------------

# %% [markdown]
# # Detokenization
